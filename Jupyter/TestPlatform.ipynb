# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import pandas as pd

silhouette_scores = []
data = pd.read_csv("./dimension_reduction_datasets/t-SNEmaxabsScaler-simpleRegressor.csv")
data = data[["PCA1", "PCA2"]]
for i in range(2, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', n_init=10, random_state=0)
    cluster_labels = kmeans.fit_predict(data)
    # save new dataframe
    data['output'] = cluster_labels
    silhouette_avg = silhouette_score(data, cluster_labels)
    silhouette_scores.append(silhouette_avg)

plt.plot(range(2, 11), silhouette_scores)
plt.title('Silhouette Analysis')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
feature1 = data["PCA1"]
feature2 = data["PCA2"]

# Scatter plot with different colors for each cluster
plt.scatter(feature1, feature2, c=cluster_labels, cmap='rainbow')
plt.title('K-Means Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
include data attributes...
Check if anything has been done with respect to this...
